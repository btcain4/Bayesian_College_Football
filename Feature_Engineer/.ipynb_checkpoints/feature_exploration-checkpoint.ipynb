# %% [markdown]
# ## Feature Engineering
# Script Name: feature_exploration.ipynb
#
# Author: Brian Cain
#
#
# The purpose of this notebook is to use the cleaned data from the Data Wrangling process and create features necessary/useful in bayesian predictive modeling. These features will also be analyzed for elements such as collinearity which will effect model making decisions. The product of this notebook will be a finalized dataframe used for predictive modeling. All functions resulting from this notebook can be found in feature_creation.ipynb.
#
# <hr>

# %%
##Import necessary packages
import pandas as pd
import numpy as np

##Pull in and display the data from the finalized data wrangling process
data = pd.read_csv('D:\\College_Football_Model_Data\\cleanData.csv')
print('Data from Data Wrangling Process:')
data.head(5)
# Out:
# Data from Data Wrangling Process:
#       gameId          school  week_num  gameSeason  homeBool  win  \
# 0  400764869          Temple         3      2015.0         1  1.0
# 1  400763604            UTEP         3      2015.0         1  1.0
# 2  400756922    Georgia Tech         3      2015.0         1  0.0
# 3  400603852  South Carolina         3      2015.0         1  0.0
# 4  400603853        Kentucky         3      2015.0         1  0.0
#
#    rush_td_movAvg  pass_td_movAvg  rush_attempt_movAvg  yp_rush_movAvg  ...  \
# 0        1.666667        1.000000            38.666667        3.766667  ...
# 1        1.666667        1.333333            41.000000        4.300000  ...
# 2        3.500000        2.500000            51.500000        6.200000  ...
# 3        1.333333        0.666667            40.000000        5.200000  ...
# 4        1.666667        1.000000            35.000000        5.000000  ...
#
#    gameControl_movAvg  completion_pct_movAvg  opp_completion_pct_movAvg  \
# 0            2.250000               0.661111                   0.514732
# 1           -7.000000               0.695013                   0.582540
# 2            5.875000               0.566667                   0.577273
# 3           -2.666667               0.509540                   0.765680
# 4            0.500000               0.509353                   0.618228
#
#    third_pct_movAvg  opp_third_pct_movAvg  fourth_pct_movAvg  \
# 0          0.405811              0.322227           0.166667
# 1          0.433333              0.405594           0.333333
# 2          0.433333              0.381818           0.833333
# 3          0.317460              0.306777           0.666667
# 4          0.325397              0.250080           0.888889
#
#    opp_fourth_pct_movAvg  diff_points_movAvg  games_played  games_won
# 0               0.333333            9.000000             3        3.0
# 1               0.833333          -27.000000             3        1.0
# 2               0.250000           23.500000             2        1.0
# 3               0.500000          -10.666667             3        1.0
# 4               0.916667            2.000000             3        2.0
#
# [5 rows x 87 columns]

# %% [markdown]
# Note that the cleaned data above still contains two records for each game. Each record contains a single teams data (home and away team). We need to compress each team record for a single game into a single record containing both team's data. A function to perform this task is written below:

# %%
def combine_data(gameRecords,columns): ##Very similar to obtain_defensive in dataAggregation.py

    ##Split data into two dataframes [homeData, awayData]
    homeData = gameRecords.loc[gameRecords['homeBool']==1,columns]
    awayData = gameRecords.loc[gameRecords['homeBool']==0,columns]

    ##Rename the columns in these dataframes
    dfs = [homeData,awayData]
    for i in range(len(dfs)):
        for j in columns:
            if j != 'gameId' and j!= 'gameSeason':
                dfs[i] = dfs[i].rename(columns={j:'opposition_'+j})

    homeData,awayData = dfs[0],dfs[1]

    ##Now join opponent offensive data onto the cleaned data frame
    new_homeData = pd.merge(gameRecords[gameRecords['homeBool']==1],
                            awayData,
                            how='left',
                            left_on=['gameId'],
                            right_on=['gameId'])
    new_awayData = pd.merge(gameRecords[gameRecords['homeBool']==0],
                            homeData,
                            how='left',
                            left_on=['gameId'],
                            right_on=['gameId'])

    ##Stack the two dataframe for our end result
    new_gameRecords_df = pd.concat([new_homeData,new_awayData])

    return new_gameRecords_df

##Conduct operation so we have all game data for both teams in a single row
cols_for_combination = ['gameId', 'homeBool', 'win',
       'rush_td_movAvg', 'pass_td_movAvg', 'rush_attempt_movAvg',
       'yp_rush_movAvg', 'rush_yards_movAvg', 'yp_pass_movAvg',
       'pass_yards_movAvg', 'total_yards_movAvg', 'turnovers_movAvg',
       'fumbles_lost_movAvg', 'interceptions_movAvg', 'firstDowns_movAvg',
       'defensive_td_movAvg', 'points_movAvg', 'elo_movAvg',
       'offensive_drives_movAvg', 'offensive_ppa_movAvg',
       'offensive_successRate_movAvg', 'offensive_explosiveness_movAvg',
       'offensive_powerSuccess_movAvg', 'offensive_stuffRate_movAvg',
       'offensive_lineYards_movAvg', 'offensive_secondLevelYards_movAvg',
       'passComplete_movAvg', 'passAttempt_movAvg', 'fourthSuccess_movAvg',
       'fourthAttempts_movAvg', 'thirdSuccess_movAvg', 'thirdAttempts_movAvg',
       'quarters_available_movAvg', 'Q1_points_movAvg', 'Q2_points_movAvg',
       'Q3_points_movAvg', 'Q4_points_movAvg', 'opp_rush_td_movAvg',
       'opp_pass_td_movAvg', 'opp_rush_attempt_movAvg', 'opp_yp_rush_movAvg',
       'opp_rush_yards_movAvg', 'opp_yp_pass_movAvg', 'opp_pass_yards_movAvg',
       'opp_total_yards_movAvg', 'opp_turnovers_movAvg',
       'opp_fumbles_lost_movAvg', 'opp_interceptions_movAvg',
       'opp_firstDowns_movAvg', 'opp_defensive_td_movAvg',
       'opp_points_movAvg', 'opp_elo_movAvg', 'opp_offensive_drives_movAvg',
       'opp_offensive_ppa_movAvg', 'opp_offensive_successRate_movAvg',
       'opp_offensive_explosiveness_movAvg',
       'opp_offensive_powerSuccess_movAvg', 'opp_offensive_stuffRate_movAvg',
       'opp_offensive_lineYards_movAvg',
       'opp_offensive_secondLevelYards_movAvg', 'opp_passComplete_movAvg',
       'opp_passAttempt_movAvg', 'opp_fourthSuccess_movAvg',
       'opp_fourthAttempts_movAvg', 'opp_thirdSuccess_movAvg',
       'opp_thirdAttempts_movAvg',
       'opp_Q1_points_movAvg', 'opp_Q2_points_movAvg', 'opp_Q3_points_movAvg',
       'opp_Q4_points_movAvg', 'gameControl_movAvg', 'completion_pct_movAvg',
       'opp_completion_pct_movAvg', 'third_pct_movAvg', 'opp_third_pct_movAvg',
       'fourth_pct_movAvg', 'opp_fourth_pct_movAvg', 'diff_points_movAvg',
       'games_played', 'games_won']

##Call function to combine game data
data = combine_data(data,cols_for_combination)
data.head()
# Out:
#       gameId          school  week_num  gameSeason  homeBool  win  \
# 0  400764869          Temple         3      2015.0         1  1.0
# 1  400763604            UTEP         3      2015.0         1  1.0
# 2  400756922    Georgia Tech         3      2015.0         1  0.0
# 3  400603852  South Carolina         3      2015.0         1  0.0
# 4  400603853        Kentucky         3      2015.0         1  0.0
#
#    rush_td_movAvg  pass_td_movAvg  rush_attempt_movAvg  yp_rush_movAvg  ...  \
# 0        1.666667        1.000000            38.666667        3.766667  ...
# 1        1.666667        1.333333            41.000000        4.300000  ...
# 2        3.500000        2.500000            51.500000        6.200000  ...
# 3        1.333333        0.666667            40.000000        5.200000  ...
# 4        1.666667        1.000000            35.000000        5.000000  ...
#
#    opposition_gameControl_movAvg  opposition_completion_pct_movAvg  \
# 0                      -4.500000                          0.549351
# 1                      -4.166667                          0.526959
# 2                       4.166667                          0.675362
# 3                       7.166667                          0.731429
# 4                       5.000000                          0.668900
#
#    opposition_opp_completion_pct_movAvg  opposition_third_pct_movAvg  \
# 0                              0.598214                     0.275735
# 1                              0.765090                     0.255342
# 2                              0.455123                     0.311688
# 3                              0.575883                     0.371083
# 4                              0.496169                     0.385392
#
#    opposition_opp_third_pct_movAvg  opposition_fourth_pct_movAvg  \
# 0                         0.510526                      0.500000
# 1                         0.544444                      0.388889
# 2                         0.247619                      0.555556
# 3                         0.325397                      0.500000
# 4                         0.297619                      1.000000
#
#    opposition_opp_fourth_pct_movAvg  opposition_diff_points_movAvg  \
# 0                          0.250000                     -18.000000
# 1                          0.666667                     -17.666667
# 2                          0.722222                      16.666667
# 3                          0.583333                      28.666667
# 4                          0.611111                      20.000000
#
#    opposition_games_played  opposition_games_won
# 0                        2                   0.0
# 1                        3                   0.0
# 2                        3                   3.0
# 3                        3                   3.0
# 4                        3                   3.0
#
# [5 rows x 166 columns]

# %% [markdown]
# <b>Important Modeling Decision:</b>
#
# A choice must be made to either model the odds the home team or away team wins. A single model for both scenarios would introduce inconsistencies in game prediction probabilities. I choose to model the probability the home team will win the game, so the dataset is modified to reflect that.

# %%
##Filter data to only be home games
data = data[data['homeBool']==1]

# %%
##Inspect the win and loss class balance for home games
print('Win/Loss Class Balance of Data:')
print('Wins: '+str(len(data[data['win']==1])))
print('Losses: '+str(len(data[data['win']==0])))
# Out:
# Win/Loss Class Balance of Data:
# Wins: 1701
# Losses: 2101

# %% [markdown]
# The data for home teams is relatively balanced, with there being more losses than wins. This is an interesting result and potential evidence to de-bunk home-field advantage, however that would require a more detailed study for another time.

# %% [markdown]
# ### Feature Creation:
#
# In this section we will explore what features are already in existence in the data and create new features based off of these. First lets explore the feature we have and the data-types they were loaded as.

# %%
##Import nice package for creating organized tables
from tabulate import tabulate

##Display current features and datatypes
colData = [['Feature','Data Type']]
for i in data.columns:
    colData.append([i,data[i].dtype])
print(tabulate(colData,headers='firstrow',tablefmt='grid'))
# Out:
# +--------------------------------------------------+-------------+
# | Feature                                          | Data Type   |
# +==================================================+=============+
# | gameId                                           | int64       |
# +--------------------------------------------------+-------------+
# | school                                           | object      |
# +--------------------------------------------------+-------------+
# | week_num                                         | int64       |
# +--------------------------------------------------+-------------+
# | gameSeason                                       | float64     |
# +--------------------------------------------------+-------------+
# | homeBool                                         | int64       |
# +--------------------------------------------------+-------------+
# | win                                              | float64     |
# +--------------------------------------------------+-------------+
# | rush_td_movAvg                                   | float64     |
# +--------------------------------------------------+-------------+
# | pass_td_movAvg                                   | float64     |
# +--------------------------------------------------+-------------+
# | rush_attempt_movAvg                              | float64     |
# +--------------------------------------------------+-------------+
# | yp_rush_movAvg                                   | float64     |
# +--------------------------------------------------+-------------+
# | rush_yards_movAvg                                | float64     |
# +--------------------------------------------------+-------------+
# | yp_pass_movAvg                                   | float64     |
# +--------------------------------------------------+-------------+
# | pass_yards_movAvg                                | float64     |
# +--------------------------------------------------+-------------+
# | total_yards_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | turnovers_movAvg                                 | float64     |
# +--------------------------------------------------+-------------+
# | fumbles_lost_movAvg                              | float64     |
# +--------------------------------------------------+-------------+
# | interceptions_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | firstDowns_movAvg                                | float64     |
# +--------------------------------------------------+-------------+
# | defensive_td_movAvg                              | float64     |
# +--------------------------------------------------+-------------+
# | points_movAvg                                    | float64     |
# +--------------------------------------------------+-------------+
# | elo_movAvg                                       | float64     |
# +--------------------------------------------------+-------------+
# | offensive_drives_movAvg                          | float64     |
# +--------------------------------------------------+-------------+
# | offensive_ppa_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | offensive_successRate_movAvg                     | float64     |
# +--------------------------------------------------+-------------+
# | offensive_explosiveness_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | offensive_powerSuccess_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | offensive_stuffRate_movAvg                       | float64     |
# +--------------------------------------------------+-------------+
# | offensive_lineYards_movAvg                       | float64     |
# +--------------------------------------------------+-------------+
# | offensive_secondLevelYards_movAvg                | float64     |
# +--------------------------------------------------+-------------+
# | passComplete_movAvg                              | float64     |
# +--------------------------------------------------+-------------+
# | passAttempt_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | fourthSuccess_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | fourthAttempts_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | thirdSuccess_movAvg                              | float64     |
# +--------------------------------------------------+-------------+
# | thirdAttempts_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | quarters_available_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | Q1_points_movAvg                                 | float64     |
# +--------------------------------------------------+-------------+
# | Q2_points_movAvg                                 | float64     |
# +--------------------------------------------------+-------------+
# | Q3_points_movAvg                                 | float64     |
# +--------------------------------------------------+-------------+
# | Q4_points_movAvg                                 | float64     |
# +--------------------------------------------------+-------------+
# | opp_rush_td_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | opp_pass_td_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | opp_rush_attempt_movAvg                          | float64     |
# +--------------------------------------------------+-------------+
# | opp_yp_rush_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | opp_rush_yards_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | opp_yp_pass_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | opp_pass_yards_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | opp_total_yards_movAvg                           | float64     |
# +--------------------------------------------------+-------------+
# | opp_turnovers_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | opp_fumbles_lost_movAvg                          | float64     |
# +--------------------------------------------------+-------------+
# | opp_interceptions_movAvg                         | float64     |
# +--------------------------------------------------+-------------+
# | opp_firstDowns_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | opp_defensive_td_movAvg                          | float64     |
# +--------------------------------------------------+-------------+
# | opp_homeBool_movAvg                              | float64     |
# +--------------------------------------------------+-------------+
# | opp_gameSeason_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | opp_team_id_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | opp_points_movAvg                                | float64     |
# +--------------------------------------------------+-------------+
# | opp_elo_movAvg                                   | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_drives_movAvg                      | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_ppa_movAvg                         | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_successRate_movAvg                 | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_explosiveness_movAvg               | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_powerSuccess_movAvg                | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_stuffRate_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_lineYards_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | opp_offensive_secondLevelYards_movAvg            | float64     |
# +--------------------------------------------------+-------------+
# | opp_passComplete_movAvg                          | float64     |
# +--------------------------------------------------+-------------+
# | opp_passAttempt_movAvg                           | float64     |
# +--------------------------------------------------+-------------+
# | opp_fourthSuccess_movAvg                         | float64     |
# +--------------------------------------------------+-------------+
# | opp_fourthAttempts_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | opp_thirdSuccess_movAvg                          | float64     |
# +--------------------------------------------------+-------------+
# | opp_thirdAttempts_movAvg                         | float64     |
# +--------------------------------------------------+-------------+
# | opp_quarters_available_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opp_Q1_points_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | opp_Q2_points_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | opp_Q3_points_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | opp_Q4_points_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | gameControl_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | completion_pct_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | opp_completion_pct_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | third_pct_movAvg                                 | float64     |
# +--------------------------------------------------+-------------+
# | opp_third_pct_movAvg                             | float64     |
# +--------------------------------------------------+-------------+
# | fourth_pct_movAvg                                | float64     |
# +--------------------------------------------------+-------------+
# | opp_fourth_pct_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | diff_points_movAvg                               | float64     |
# +--------------------------------------------------+-------------+
# | games_played                                     | int64       |
# +--------------------------------------------------+-------------+
# | games_won                                        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_homeBool                              | int64       |
# +--------------------------------------------------+-------------+
# | opposition_win                                   | float64     |
# +--------------------------------------------------+-------------+
# | opposition_rush_td_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_pass_td_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_rush_attempt_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | opposition_yp_rush_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_rush_yards_movAvg                     | float64     |
# +--------------------------------------------------+-------------+
# | opposition_yp_pass_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_pass_yards_movAvg                     | float64     |
# +--------------------------------------------------+-------------+
# | opposition_total_yards_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_turnovers_movAvg                      | float64     |
# +--------------------------------------------------+-------------+
# | opposition_fumbles_lost_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | opposition_interceptions_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_firstDowns_movAvg                     | float64     |
# +--------------------------------------------------+-------------+
# | opposition_defensive_td_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | opposition_points_movAvg                         | float64     |
# +--------------------------------------------------+-------------+
# | opposition_elo_movAvg                            | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_drives_movAvg               | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_ppa_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_successRate_movAvg          | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_explosiveness_movAvg        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_powerSuccess_movAvg         | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_stuffRate_movAvg            | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_lineYards_movAvg            | float64     |
# +--------------------------------------------------+-------------+
# | opposition_offensive_secondLevelYards_movAvg     | float64     |
# +--------------------------------------------------+-------------+
# | opposition_passComplete_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | opposition_passAttempt_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_fourthSuccess_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_fourthAttempts_movAvg                 | float64     |
# +--------------------------------------------------+-------------+
# | opposition_thirdSuccess_movAvg                   | float64     |
# +--------------------------------------------------+-------------+
# | opposition_thirdAttempts_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_quarters_available_movAvg             | float64     |
# +--------------------------------------------------+-------------+
# | opposition_Q1_points_movAvg                      | float64     |
# +--------------------------------------------------+-------------+
# | opposition_Q2_points_movAvg                      | float64     |
# +--------------------------------------------------+-------------+
# | opposition_Q3_points_movAvg                      | float64     |
# +--------------------------------------------------+-------------+
# | opposition_Q4_points_movAvg                      | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_rush_td_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_pass_td_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_rush_attempt_movAvg               | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_yp_rush_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_rush_yards_movAvg                 | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_yp_pass_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_pass_yards_movAvg                 | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_total_yards_movAvg                | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_turnovers_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_fumbles_lost_movAvg               | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_interceptions_movAvg              | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_firstDowns_movAvg                 | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_defensive_td_movAvg               | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_points_movAvg                     | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_elo_movAvg                        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_drives_movAvg           | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_ppa_movAvg              | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_successRate_movAvg      | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_explosiveness_movAvg    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_powerSuccess_movAvg     | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_stuffRate_movAvg        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_lineYards_movAvg        | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_offensive_secondLevelYards_movAvg | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_passComplete_movAvg               | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_passAttempt_movAvg                | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_fourthSuccess_movAvg              | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_fourthAttempts_movAvg             | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_thirdSuccess_movAvg               | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_thirdAttempts_movAvg              | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_Q1_points_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_Q2_points_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_Q3_points_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_Q4_points_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_gameControl_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_completion_pct_movAvg                 | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_completion_pct_movAvg             | float64     |
# +--------------------------------------------------+-------------+
# | opposition_third_pct_movAvg                      | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_third_pct_movAvg                  | float64     |
# +--------------------------------------------------+-------------+
# | opposition_fourth_pct_movAvg                     | float64     |
# +--------------------------------------------------+-------------+
# | opposition_opp_fourth_pct_movAvg                 | float64     |
# +--------------------------------------------------+-------------+
# | opposition_diff_points_movAvg                    | float64     |
# +--------------------------------------------------+-------------+
# | opposition_games_played                          | int64       |
# +--------------------------------------------------+-------------+
# | opposition_games_won                             | float64     |
# +--------------------------------------------------+-------------+

# %% [markdown]
# The datatypes of the available features look correct. We can not move directly to some feature creation.
#
# <b>Difference of Statistic Features:</b>
#
# A single game record contains each teams...

# %% [markdown]
# ### Feature Analysis/Collinearity
