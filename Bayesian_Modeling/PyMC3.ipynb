# %%
##Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

##Pull in and display the data
data = pd.read_csv('D:\\College_Football_Model_Data\\modelData.csv')
data.head()
# Out:
#       gameId          school  week_num  gameSeason  win  \
# 0  400764869          Temple         3      2015.0  1.0
# 1  400763604            UTEP         3      2015.0  1.0
# 2  400756922    Georgia Tech         3      2015.0  0.0
# 3  400603852  South Carolina         3      2015.0  0.0
# 4  400603853        Kentucky         3      2015.0  0.0
#
#    offDiff_rush_td_movAvg  defDiff_pass_td_movAvg  offDiff_yp_rush_movAvg  \
# 0               -1.333333               -0.333333               -0.433333
# 1               -1.333333                1.333333               -1.133333
# 2                2.500000               -1.333333                2.566667
# 3                0.666667               -0.666667                2.233333
# 4                1.333333               -1.666667                3.300000
#
#    defDiff_pass_yards_movAvg  offDiff_total_yards_movAvg  \
# 0                 -13.833333                 -151.000000
# 1                  57.333333                 -190.000000
# 2                 -44.500000                  148.666667
# 3                  30.333333                   53.333333
# 4                 -45.000000                  100.333333
#
#    defDiff_turnovers_movAvg  defDiff_firstDowns_movAvg  \
# 0                  0.666667                   1.000000
# 1                 -0.666667                   4.333333
# 2                  1.333333                  -4.833333
# 3                  1.000000                   0.333333
# 4                  0.666667                   1.333333
#
#    defDiff_offensive_ppa_movAvg  offDiff_offensive_powerSuccess_movAvg  \
# 0                     -0.047219                              -0.089744
# 1                      0.346266                               0.111111
# 2                     -0.166122                               0.444444
# 3                     -0.097716                              -0.022222
# 4                     -0.124125                              -0.111111
#
#    defDiff_completion_pct_movAvg  defDiff_third_pct_movAvg  \
# 0                      -0.034619                  0.046491
# 1                       0.055580                  0.150253
# 2                      -0.098090                  0.070130
# 3                       0.034252                 -0.064306
# 4                      -0.050671                 -0.135313
#
#    gameDiff_gameControl_movAvg  gameDiff_elo_movAvg
# 0                     6.750000           324.833333
# 1                    -2.833333           225.666667
# 2                     1.708333           172.333333
# 3                    -9.833333          -240.333333
# 4                    -4.500000          -290.333333

# %%
##Perform z-score normalization of the data
def z_score_normalization(df,col):
    
    ##Compute variables necessary for this 
    mu = np.mean(df[col])
    std = np.std(df[col])
    
    ##Replace column with normalized column
    df[col] = (df[col]-mu)/std
    
    return df

##Now perform normalization
predictors = ['offDiff_rush_td_movAvg', 'defDiff_pass_td_movAvg',
       'offDiff_yp_rush_movAvg', 'defDiff_pass_yards_movAvg',
       'offDiff_total_yards_movAvg', 'defDiff_turnovers_movAvg',
       'defDiff_firstDowns_movAvg', 'defDiff_offensive_ppa_movAvg',
       'offDiff_offensive_powerSuccess_movAvg',
       'defDiff_completion_pct_movAvg', 'defDiff_third_pct_movAvg',
       'gameDiff_gameControl_movAvg', 'gameDiff_elo_movAvg']
for i in predictors:
    data = z_score_normalization(data,i)
data.head()
# Out:
#       gameId          school  week_num  gameSeason  win  \
# 0  400764869          Temple         3      2015.0  1.0
# 1  400763604            UTEP         3      2015.0  1.0
# 2  400756922    Georgia Tech         3      2015.0  0.0
# 3  400603852  South Carolina         3      2015.0  0.0
# 4  400603853        Kentucky         3      2015.0  0.0
#
#    offDiff_rush_td_movAvg  defDiff_pass_td_movAvg  offDiff_yp_rush_movAvg  \
# 0               -1.371113               -0.399361               -0.374039
# 1               -1.371113                1.441503               -0.947174
# 2                2.502526               -1.503880                2.082252
# 3                0.649916               -0.767534                1.809331
# 4                1.323592               -1.872053                2.682679
#
#    defDiff_pass_yards_movAvg  offDiff_total_yards_movAvg  \
# 0                  -0.262128                   -1.743327
# 1                   0.798175                   -2.181374
# 2                  -0.719026                    1.622522
# 3                   0.395906                    0.551740
# 4                  -0.726476                    1.079643
#
#    defDiff_turnovers_movAvg  defDiff_firstDowns_movAvg  \
# 0                  0.938524                   0.203776
# 1                 -0.964484                   1.017180
# 2                  1.890027                  -1.219681
# 3                  1.414276                   0.041095
# 4                  0.938524                   0.285116
#
#    defDiff_offensive_ppa_movAvg  offDiff_offensive_powerSuccess_movAvg  \
# 0                     -0.354374                              -0.651392
# 1                      2.496855                               0.710578
# 2                     -1.215956                               2.970868
# 3                     -0.720285                              -0.193538
# 4                     -0.911648                              -0.796282
#
#    defDiff_completion_pct_movAvg  defDiff_third_pct_movAvg  \
# 0                      -0.444200                  0.500301
# 1                       0.710779                  1.656307
# 2                      -1.256929                  0.763657
# 3                       0.437671                 -0.734100
# 4                      -0.649748                 -1.525188
#
#    gameDiff_gameControl_movAvg  gameDiff_elo_movAvg
# 0                     1.375274             1.300499
# 1                    -0.440968             0.947893
# 2                     0.419773             0.758256
# 3                    -1.767614            -0.709059
# 4                    -0.756836            -0.886843

# %%
import pymc3
import arviz as az

basic_model = pm.Model()

with basic_model:

    # Priors for unknown model parameters
    lambda_ = pm.Exponential("lambda", 1.5)
    beta = pm.Normal("beta", mu=0, sigma=1/(2*lambda_), shape=13)
    sigma = pm.HalfNormal("sigma", sigma=1)

    # Expected value of outcome
    mu = alpha + beta[0] * X1 + beta[1] * X2

    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal("Y_obs", mu=mu, sigma=sigma, observed=Y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-2ce7a5168dcb> in <module>
# ----> 1 import pymc3
#       2 import arviz as az
#       3
#       4 basic_model = pm.Model()
#       5
#
# ~\anaconda3\lib\site-packages\pymc3\__init__.py in <module>
#      11 from .model_graph import model_to_graphviz
#      12 from . import ode
# ---> 13 from .stats import *
#      14 from .sampling import *
#      15 from .step_methods import *
#
# ~\anaconda3\lib\site-packages\pymc3\stats\__init__.py in <module>
#       8 import warnings
#       9
# ---> 10 import arviz as az
#      11
#      12 def map_args(func):
#
# ModuleNotFoundError: No module named 'arviz'
